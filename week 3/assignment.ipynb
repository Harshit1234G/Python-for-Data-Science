# %%
import pandas as pd

# %%
flavors = pd.read_csv("flavors_of_cocoa.csv", index_col= 0)

# %%
flavors
# Out:
#        Company         Bean Origin  Review Date Cocoa Percent  \
# Id
# 1     A. Morin         Agua Grande       2016.0           63%
# 2     A. Morin               Kpime       2015.0           70%
# 3     A. Morin              Atsane       2015.0           70%
# 4     A. Morin               Akata       2015.0           70%
# 5     A. Morin              Quilla       2015.0           70%
# ...        ...                 ...          ...           ...
# 1791    Zotter                Peru       2011.0           70%
# 1792    Zotter               Congo       2011.0           65%
# 1793    Zotter        Kerala State       2011.0           65%
# 1794    Zotter        Kerala State       2011.0           62%
# 1795    Zotter  Brazil, Mitzi Blue       2010.0           65%
#
#      Company Location  Rating
# Id
# 1              France    3.75
# 2              France    2.75
# 3              France    3.00
# 4              France    3.50
# 5              France    3.50
# ...

# %%
flavors.isnull().sum()
# Out:
# Company             0
# Bean Origin         0
# Review Date         4
# Cocoa Percent       0
# Company Location    0
# Rating              0
# dtype: int64

# %%
flavors["Company Location"].value_counts()
# Out:
# Company Location
# U.S.A.               764
# France               156
# Canada               125
# U.K.                  96
# Italy                 63
# Ecuador               54
# Australia             49
# Belgium               40
# Switzerland           38
# Germany               35
# Austria               26
# Spain                 25
# Colombia              23
# Hungary               22
# Venezuela             20
# Japan                 17
# Brazil                17
# Peru                  17
# Madagascar            17
# New Zealand           17
# Denmark               15
# Vietnam               11
# Scotland              10
# Guatemala             10
# Israel                 9
# Costa Rica             9
# Argentina              9
# Poland                 8
# Lithuania              6
# Honduras               6
# South Korea            5
# Nicaragua              5
# Sweden                 5
# Domincan Republic      5
# Ireland                4
# Netherlands            4
# ...

# %%
flavors.dtypes
# Out:
# Company              object
# Bean Origin          object
# Review Date         float64
# Cocoa Percent        object
# Company Location     object
# Rating              float64
# dtype: object

# %%
flavors.head()
# Out:
#      Company  Bean Origin  Review Date Cocoa Percent Company Location  Rating
# Id
# 1   A. Morin  Agua Grande       2016.0           63%           France    3.75
# 2   A. Morin        Kpime       2015.0           70%           France    2.75
# 3   A. Morin       Atsane       2015.0           70%           France    3.00
# 4   A. Morin        Akata       2015.0           70%           France    3.50
# 5   A. Morin       Quilla       2015.0           70%           France    3.50
